# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy.stats import zscore
df=pd.read_csv("house_price.csv")

# %%
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# 2                4305
# 3                6245
# 4                4250
# ...               ...
# 13195            6689
# 13196           11111
# 13197            5258
# 13198           10407
# 13199            3090
#
# [13200 rows x 7 columns]

# %%
df["price_per_sqft"].describe()
# Out:
# count    1.320000e+04
# mean     7.920337e+03
# std      1.067272e+05
# min      2.670000e+02
# 25%      4.267000e+03
# 50%      5.438000e+03
# 75%      7.317000e+03
# max      1.200000e+07
# Name: price_per_sqft, dtype: float64

# %% [markdown]
# ### MEAN FUNCTION

# %%
m=df.price_per_sqft .mean()
m
# Out:
# 7920.336742424242

# %%
s=df.price_per_sqft.std()
s
# Out:
# 106727.16032810867

# %%
m-3*s
# Out:
# -312261.14424190175

# %%
m+3*s
# Out:
# 328101.8177267502

# %%
# Values less than -312261 and greater than 328101 are the outliers

# %%
df_withoutoutlier=df[(df.price_per_sqft>-312261)& (df.price_per_sqft<328101)]
df_withoutoutlier
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft    zscore
# 0                3699 -0.039553
# 1                4615 -0.030970
# 2                4305 -0.033875
# 3                6245 -0.015697
# 4                4250 -0.034390
# ...               ...       ...
# 13195            6689 -0.011537
# 13196           11111  0.029896
# 13197            5258 -0.024945
# 13198           10407  0.023299
# 13199            3090 -0.045259
#
# [13195 rows x 8 columns]

# %% [markdown]
# ### IQR FUNCTION

# %%
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1
Q1
Q3
IQR
# Out:
# 3050.0

# %%
lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

lower,upper
# Out:
# (-308.0, 11892.0)

# %%
df[(df.price_per_sqft<-308) | (df.price_per_sqft>11892)]  #outliers
# Out:
#                location       size  total_sqft  bath  price  bhk  \
# 7          Rajaji Nagar      4 BHK      3300.0   4.0  600.0    4
# 9                 other  6 Bedroom      1020.0   6.0  370.0    6
# 22          Thanisandra  4 Bedroom      2800.0   5.0  380.0    4
# 45           HSR Layout  8 Bedroom       600.0   9.0  200.0    8
# 48             KR Puram  2 Bedroom       800.0   1.0  130.0    2
# ...                 ...        ...         ...   ...    ...  ...
# 13142             other      2 BHK      1140.0   1.0  185.0    2
# 13157             other  7 Bedroom      1400.0   7.0  218.0    7
# 13185          Hulimavu      1 BHK       500.0   1.0  220.0    1
# 13186             other  4 Bedroom      1200.0   5.0  325.0    4
# 13191  Ramamurthy Nagar  7 Bedroom      1500.0   9.0  250.0    7
#
#        price_per_sqft
# 7               18181
# 9               36274
# 22              13571
# 45              33333
# 48              16250
# ...               ...
# 13142           16228
# 13157           15571
# 13185           44000
# 13186           27083
# 13191           16666
#
# [1265 rows x 7 columns]

# %%
df_without_outlier=df[(df.price_per_sqft>-308) & (df.price_per_sqft<11892)]   #without outliers
df_without_outlier
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# 2                4305
# 3                6245
# 4                4250
# ...               ...
# 13195            6689
# 13196           11111
# 13197            5258
# 13198           10407
# 13199            3090
#
# [11935 rows x 7 columns]

# %%
from matplotlib import pyplot as plt

# %%
#### BOX PLOT

# %%
#without outliers
plt.boxplot(df_without_outlier['price_per_sqft'])
plt.show()

# %% [markdown]
# ### zscore Method

# %%
df["zscore"]=(df.price_per_sqft-m)/s 
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft    zscore
# 0                3699 -0.039553
# 1                4615 -0.030970
# 2                4305 -0.033875
# 3                6245 -0.015697
# 4                4250 -0.034390
# ...               ...       ...
# 13195            6689 -0.011537
# 13196           11111  0.029896
# 13197            5258 -0.024945
# 13198           10407  0.023299
# 13199            3090 -0.045259
#
# [13200 rows x 8 columns]

# %%
df[(df.zscore>-3) & (df.zscore<3)]
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft    zscore
# 0                3699 -0.039553
# 1                4615 -0.030970
# 2                4305 -0.033875
# 3                6245 -0.015697
# 4                4250 -0.034390
# ...               ...       ...
# 13195            6689 -0.011537
# 13196           11111  0.029896
# 13197            5258 -0.024945
# 13198           10407  0.023299
# 13199            3090 -0.045259
#
# [13195 rows x 8 columns]

# %%
df1=df.drop(["zscore","location","size"],axis=1)
df1
# Out:
#        total_sqft  bath   price  bhk  price_per_sqft
# 0          1056.0   2.0   39.07    2            3699
# 1          2600.0   5.0  120.00    4            4615
# 2          1440.0   2.0   62.00    3            4305
# 3          1521.0   3.0   95.00    3            6245
# 4          1200.0   2.0   51.00    2            4250
# ...           ...   ...     ...  ...             ...
# 13195      3453.0   4.0  231.00    5            6689
# 13196      3600.0   5.0  400.00    4           11111
# 13197      1141.0   2.0   60.00    2            5258
# 13198      4689.0   4.0  488.00    4           10407
# 13199       550.0   1.0   17.00    1            3090
#
# [13200 rows x 5 columns]

# %%
corr1=df1.corr()
corr1
# Out:
#                 total_sqft      bath     price       bhk  price_per_sqft
# total_sqft        1.000000  0.392743  0.574330  0.346013       -0.008267
# bath              0.392743  1.000000  0.455998  0.897951        0.030883
# price             0.574330  0.455998  1.000000  0.396883        0.028387
# bhk               0.346013  0.897951  0.396883  1.000000        0.030955
# price_per_sqft   -0.008267  0.030883  0.028387  0.030955        1.000000

# %%
sns.scatterplot(data=df, x='total_sqft', y='price', sizes=(20, 200), palette='viridis')

sns.scatterplot(data=df, x='total_sqft', y='price')

plt.title('Scatter Plot of Variables')
plt.xlabel('Total Square Feet')
plt.ylabel('Price')
plt.show()
# Out:
# C:\Users\anush\AppData\Local\Temp\ipykernel_39520\1128936178.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='total_sqft', y='price', sizes=(20, 200), palette='viridis')

# %%
sns.heatmap(corr1,annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(data=df_withoutoutlier,x=df_withoutoutlier.price_per_sqft,kde=True) #kde is for showing bars
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
sns.boxplot(data=df[['price_per_sqft']])
plt.show()
